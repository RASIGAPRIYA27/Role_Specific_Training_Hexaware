# %%
bank_data = [
(101,"Hyderabad",50000),
(102,"Hyderabad",25000),
(103,"Bangalore",60000),
(104,"Delhi",35000),
(105,"Chennai",45000)
]

columns = [
"account_id",
"city",
"balance"
]

# %%
bank_df = spark.createDataFrame(bank_data,columns)

# %%
bank_df.groupBy("city").sum("balance").show()
# Out:
# +---------+------------+
# |     city|sum(balance)|
# +---------+------------+
# |Hyderabad|       75000|
# |Bangalore|       60000|
# |    Delhi|       35000|
# |  Chennai|       45000|
# +---------+------------+
