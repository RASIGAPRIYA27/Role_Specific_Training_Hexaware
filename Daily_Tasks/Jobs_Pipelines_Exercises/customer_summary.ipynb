# %%
customers = spark.table("customer_table")

# %%
customers.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Hyderabad|    2|
# |Bangalore|    1|
# |   Mumbai|    1|
# |    Delhi|    1|
# +---------+-----+
